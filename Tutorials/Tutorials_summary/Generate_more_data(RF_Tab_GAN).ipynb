# %%
# %%capture
# %pip install -U 'rockfish[labs]' -f 'https://docs142.rockfish.ai/packages/index.html'

# %%
import rockfish as rf
import rockfish.actions as ra
import rockfish.labs

# %% [markdown]
# Please replace `YOUR_API_KEY` with the assigned API key string. Note that it should be without quotes.
#
# For example, if the assigned API Key is `abcd1234`, you can do the following
# ```python
# %env ROCKFISH_API_KEY=abcd1234
# conn = rf.Connection.from_env()
# ```
# If you do not have API Key, please reach out to support@rockfish.ai.

# %%
# %env ROCKFISH_API_KEY=YOUR_API_KEY
conn = rf.Connection.from_env()

# %%
# download our example of tabular data: fall_detection.csv
# !wget --no-clobber https://docs142.rockfish.ai/tutorials/fall_detection.csv
# Out:
# File ‘fall_detection.csv’ already there; not retrieving.

# %%
dataset = rf.Dataset.from_csv("fall_detection", "fall_detection.csv")
dataset.to_pandas()
# Out:
#      Age range of patient Sex  \
# 0                   60<70   M
# 1                   30<40   F
# 2                   60<70   M
# 3                   80<90   M
# 4                   60<70   M
# ...                   ...  ..
# 2577                50<60   M
# 2578                80<90   F
# 2579                30<40   F
# 2580                60<70   M
# 2581                50<60   F
#
#      Involvement of medication associated with fall risk  \
# 0                                                   Yes
# 1                                                   Yes
# 2                                                   Yes
# 3                                                   Yes
# 4                                                   Yes
# ...                                                 ...
# 2577                                                 No
# 2578                                                 No
# 2579                                                 No
# 2580                                                 No
# 2581                                                Yes
#
#      Whether a fall prevention protocol was implemented Reason for incident  \
# 0                                                   Yes                Slip
# 1                                                   Yes     Loss of balance
# 2                                                   Yes    Mental confusion
# 3                                                   Yes    Mental confusion
# 4                                                   Yes     Loss of balance
# ...                                                 ...                 ...
# 2577                                                 No     Muscle weakness
# 2578                                                 No         Hypotension
# 2579                                                 No     Muscle weakness
# 2580                                                Yes     Loss of balance
# 2581                                                 No     Muscle weakness
#
#      Whether a restraint prescription was given  \
# 0                                            No
# 1                                            No
# 2                                            No
# 3                                            No
# 4                                            No
# ...                                         ...
# 2577                                         No
# 2578                                         No
# 2579                                         No
# 2580                                         No
# 2581                                         No
#
#      Whether a physical therapy prescription was given  BBS Score  \
# 0                                                  Yes         41
# 1                                                   No         41
# 2                                                  Yes         43
# 3                                                  Yes         40
# 4                                                  Yes         40
# ...                                                ...        ...
# 2577                                                No         44
# 2578                                                No         43
# 2579                                                No         43
# 2580                                                No         44
# 2581                                                No         44
#
#       Body Temperature  Heart Rate  ...  Chronic Heart Failure  Stroke  \
# 0                   97          80  ...                     No      No
# 1                   96          78  ...                     No      No
# 2                   98          81  ...                     No      No
# 3                   99          82  ...                     No      No
# 4                   96          90  ...                     No      No
# ...                ...         ...  ...                    ...     ...
# 2577                97          67  ...                     No      No
# 2578                97          96  ...                     No      No
# 2579                96          76  ...                     No      No
# 2580                99         101  ...                     No      No
# 2581                97          71  ...                     No      No
#
#       Frozen shoulder  Osteoarthritis of hip Cerebellar Ataxia Hemiparesis  \
# 0                  No                     No                No          No
# 1                  No                     No                No          No
# 2                  No                     No                No          No
# 3                  No                     No                No          No
# 4                  No                     No                No          No
# ...               ...                    ...               ...         ...
# 2577               No                     No                No          No
# 2578               No                     No                No          No
# 2579               No                     No                No          No
# 2580               No                     No                No          No
# 2581               No                     No                No          No
#
#      GB Syndrome Fall risk level Ischemic Heart Disease Cervical sopondylitis
# 0             No            High                     No                    No
# 1             No            High                     No                    No
# 2             No            High                     No                    No
# 3             No            High                     No                    No
# 4             No            High                     No                    No
# ...          ...             ...                    ...                   ...
# 2577          No        Moderate                     No                    No
# 2578          No        Moderate                     No                    No
# 2579          No        Moderate                     No                    No
# 2580          No        Moderate                     No                    No
# 2581          No        Moderate                     No                   Yes
#
# [2582 rows x 43 columns]

# %%
# user can manually provide a list of categorical column names
categorical_fields = dataset.to_pandas().select_dtypes(include=["object"]).columns
config = {
    "encoder": {
        "metadata": [
            {"field": field, "type": "categorical"} for field in categorical_fields
        ]
        + [
            {"field": field, "type": "continuous"}
            for field in dataset.table.column_names
            if field not in categorical_fields
        ],
    },
    "tabular-gan": {
        "epochs": 100,
        "records": 2582,
    },
}
# create train action
train = ra.TrainTabGAN(config)

# %%
builder = rf.WorkflowBuilder()
builder.add_dataset(dataset)
builder.add_action(train, parents=[dataset])
workflow = await builder.start(conn)

print(f"Workflow: {workflow.id()}")
# Out:
# Workflow: 1izmeQThaSbyKJqpmiIVkT

# %%
async for progress in workflow.progress().notebook():
    pass
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
model = await workflow.models().nth(0)
model
# Out:
# Model('4ac4674a-4096-11ef-8c4e-8a07ae1c625c')

# %% [markdown]
# ### Update the generated records

# %%
config["tabular-gan"].update({"records": 5000})  # update n_records
generate = ra.GenerateTabGAN(config)
save = ra.DatasetSave({"name": "synthetic"})
builder = rf.WorkflowBuilder()
builder.add_model(model)
builder.add_action(generate, parents=[model])
builder.add_action(save, parents=[generate])
workflow = await builder.start(conn)
print(f"Workflow: {workflow.id()}")
# Out:
# Workflow: 1JQF6IfIJJ4dBr0Z5dmVz3

# %%
async for log in workflow.logs():
    print(log)
# Out:
# 2024-07-12T21:33:41Z dataset-save: INFO Saved dataset '7w5W9HGR04i1RBFMRoJEo9' with 5000 rows
# 2024-07-12T21:33:40Z generate-tab-gan: INFO Generating 5000 records

# %%
syn = None
async for sds in workflow.datasets():
    syn = await sds.to_local(conn)
syn.to_pandas()
# Out:
#      Age range of patient Sex  \
# 0                   60<70   F
# 1                   70<80   M
# 2                   70<80   M
# 3                   20<30   F
# 4                   80<90   M
# ...                   ...  ..
# 4995                60<70   F
# 4996                 1<13   F
# 4997                50<60   M
# 4998                40<50   F
# 4999                  < 1   F
#
#      Involvement of medication associated with fall risk  \
# 0                                                    No
# 1                                                   Yes
# 2                                                   Yes
# 3                                                   Yes
# 4                                                   Yes
# ...                                                 ...
# 4995                                                 No
# 4996                                                Yes
# 4997                                                 No
# 4998                                                Yes
# 4999                                                Yes
#
#      Whether a fall prevention protocol was implemented Reason for incident  \
# 0                                                    No    Mental confusion
# 1                                                   Yes     Muscle weakness
# 2                                                   Yes     Muscle weakness
# 3                                                   Yes     Loss of balance
# 4                                                   Yes     Loss of balance
# ...                                                 ...                 ...
# 4995                                                Yes         Hypotension
# 4996                                                Yes    Mental confusion
# 4997                                                Yes     Muscle weakness
# 4998                                                Yes         Hypotension
# 4999                                                Yes                Trip
#
#      Whether a restraint prescription was given  \
# 0                                            No
# 1                                            No
# 2                                            No
# 3                                            No
# 4                                            No
# ...                                         ...
# 4995                                         No
# 4996                                         No
# 4997                                         No
# 4998                                         No
# 4999                                         No
#
#      Whether a physical therapy prescription was given  BBS Score  \
# 0                                                   No         39
# 1                                                   No         54
# 2                                                   No         37
# 3                                                   No         40
# 4                                                  Yes         39
# ...                                                ...        ...
# 4995                                                No         44
# 4996                                               Yes         43
# 4997                                               Yes         41
# 4998                                                No         39
# 4999                                                No         40
#
#       Body Temperature  Heart Rate  ...  Chronic Heart Failure  Stroke  \
# 0                   97          95  ...                     No      No
# 1                   97          76  ...                     No      No
# 2                   96          72  ...                     No      No
# 3                   98          90  ...                     No      No
# 4                   97          72  ...                     No      No
# ...                ...         ...  ...                    ...     ...
# 4995                98          80  ...                     No      No
# 4996                97         105  ...                     No      No
# 4997                98         109  ...                     No      No
# 4998                96          91  ...                     No      No
# 4999                97          90  ...                     No      No
#
#       Frozen shoulder  Osteoarthritis of hip Cerebellar Ataxia Hemiparesis  \
# 0                  No                     No                No          No
# 1                  No                     No                No          No
# 2                  No                     No                No          No
# 3                  No                     No                No          No
# 4                  No                     No                No          No
# ...               ...                    ...               ...         ...
# 4995              Yes                     No                No          No
# 4996               No                     No                No          No
# 4997               No                     No                No          No
# 4998               No                     No                No          No
# 4999              Yes                     No               Yes          No
#
#      GB Syndrome Fall risk level Ischemic Heart Disease Cervical sopondylitis
# 0             No            High                     No                    No
# 1             No            High                     No                    No
# 2             No            High                     No                    No
# 3             No             Low                     No                    No
# 4             No            High                     No                    No
# ...          ...             ...                    ...                   ...
# 4995          No        Moderate                     No                    No
# 4996          No            High                     No                    No
# 4997          No            High                    Yes                    No
# 4998          No            High                     No                    No
# 4999          No        Moderate                     No                    No
#
# [5000 rows x 43 columns]

# %% [markdown]
# ### Generate large dataset
# We recommend you to use our `SessionTarget` and please refer [here](https://docs142.rockfish.ai/data-gen.html#tabular-data) for details

# %%
record_target = ra.SessionTarget(target=20000)  # providing the target "records" value
save = ra.DatasetSave(name="target_synthetic", concat_tables=True)
builder = rf.WorkflowBuilder()
builder.add_model(model)
builder.add_action(generate, parents=[model, record_target])
builder.add_action(record_target, parents=[generate])
builder.add_action(save, parents=[generate])
workflow = await builder.start(conn)
print(f"Workflow: {workflow.id()}")
# Out:
# Workflow: 4z3Ev4H6LsnmhWhOJBf8kM

# %%
async for log in workflow.logs():
    print(log)
# Out:
# 2024-07-12T21:32:55Z generate-tab-gan: INFO Generating 5000 records
# 2024-07-12T21:32:56Z session-target: INFO new=5000 total=5000 needs=15000
# 2024-07-12T21:32:56Z dataset-save: INFO Saved dataset '4QOVnz5mrVMum3KwPeyjc3' with 5000 rows
# 2024-07-12T21:32:56Z generate-tab-gan: INFO Generating 5000 records
# 2024-07-12T21:32:56Z session-target: INFO new=5000 total=10000 needs=10000
# 2024-07-12T21:32:57Z generate-tab-gan: INFO Generating 5000 records
# 2024-07-12T21:32:57Z session-target: INFO new=5000 total=15000 needs=5000
# 2024-07-12T21:32:57Z generate-tab-gan: INFO Generating 5000 records
# 2024-07-12T21:32:58Z session-target: INFO new=5000 total=20000 needs=0

# %%
syn_large = None
async for sds in workflow.datasets():
    syn_large = await sds.to_local(conn)
syn_large.to_pandas()
# Out:
#       Age range of patient Sex  \
# 0                    70<80   F
# 1                    60<70   M
# 2                      < 1   F
# 3                    60<70   M
# 4                    60<70   F
# ...                    ...  ..
# 19995                40<50   F
# 19996                60<70   M
# 19997                 ≥ 90   F
# 19998                  < 1   F
# 19999                70<80   F
#
#       Involvement of medication associated with fall risk  \
# 0                                                     No
# 1                                                    Yes
# 2                                                    Yes
# 3                                                     No
# 4                                                    Yes
# ...                                                  ...
# 19995                                                 No
# 19996                                                Yes
# 19997                                                 No
# 19998                                                Yes
# 19999                                                Yes
#
#       Whether a fall prevention protocol was implemented Reason for incident  \
# 0                                                    Yes     Muscle weakness
# 1                                                    Yes     Loss of balance
# 2                                                     No    Mental confusion
# 3                                                    Yes         Hypotension
# 4                                                    Yes    Mental confusion
# ...                                                  ...                 ...
# 19995                                                Yes     Loss of balance
# 19996                                                Yes    Mental confusion
# 19997                                                Yes     Loss of balance
# 19998                                                Yes         Hypotension
# 19999                                                Yes     Muscle weakness
#
#       Whether a restraint prescription was given  \
# 0                                             No
# 1                                             No
# 2                                             No
# 3                                             No
# 4                                             No
# ...                                          ...
# 19995                                         No
# 19996                                         No
# 19997                                         No
# 19998                                         No
# 19999                                         No
#
#       Whether a physical therapy prescription was given  BBS Score  \
# 0                                                    No         44
# 1                                                    No         35
# 2                                                    No         38
# 3                                                    No         41
# 4                                                   Yes         38
# ...                                                 ...        ...
# 19995                                                No         53
# 19996                                               Yes         44
# 19997                                                No         39
# 19998                                               Yes         44
# 19999                                                No         43
#
#        Body Temperature  Heart Rate  ...  Chronic Heart Failure  Stroke  \
# 0                    97         107  ...                     No      No
# 1                    98          88  ...                     No      No
# 2                    97          92  ...                     No      No
# 3                    97          76  ...                     No      No
# 4                    98          70  ...                     No      No
# ...                 ...         ...  ...                    ...     ...
# 19995                97          82  ...                     No      No
# 19996                98          71  ...                     No      No
# 19997                97          91  ...                     No      No
# 19998                98         109  ...                    Yes      No
# 19999                98          98  ...                     No      No
#
#        Frozen shoulder  Osteoarthritis of hip Cerebellar Ataxia Hemiparesis  \
# 0                   No                     No                No          No
# 1                   No                     No                No          No
# 2                   No                     No                No          No
# 3                   No                     No                No          No
# 4                   No                     No               Yes          No
# ...                ...                    ...               ...         ...
# 19995               No                     No                No          No
# 19996               No                    Yes                No          No
# 19997               No                     No                No          No
# 19998               No                     No                No          No
# 19999               No                     No                No          No
#
#       GB Syndrome Fall risk level Ischemic Heart Disease Cervical sopondylitis
# 0              No            High                     No                    No
# 1              No        Moderate                     No                    No
# 2              No            High                     No                    No
# 3              No            High                     No                    No
# 4              No            High                     No                    No
# ...           ...             ...                    ...                   ...
# 19995          No        Moderate                     No                    No
# 19996          No            High                     No                    No
# 19997          No        Moderate                     No                    No
# 19998          No        Moderate                     No                    No
# 19999          No        Moderate                     No                    No
#
# [20000 rows x 43 columns]
