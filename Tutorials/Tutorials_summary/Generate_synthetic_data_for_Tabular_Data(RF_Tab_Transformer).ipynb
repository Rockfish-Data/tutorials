# %%
# %%capture
# %pip install -U 'rockfish[labs]' -f 'https://docs142.rockfish.ai/packages/index.html'

# %%
import rockfish as rf
import rockfish.actions as ra
import rockfish.labs

# %% [markdown]
# Please replace `YOUR_API_KEY` with the assigned API key string. Note that it should be without quotes.
#
# For example, if the assigned API Key is `abcd1234`, you can do the following
# ```python
# %env ROCKFISH_API_KEY=abcd1234
# conn = rf.Connection.from_env()
# ```
# If you do not have API Key, please reach out to support@rockfish.ai.

# %%
# %env ROCKFISH_API_KEY=YOUR_API_KEY
conn = rf.Connection.from_env()

# %%
# download our example of tabular data: spotify-2023-short.csv
# !wget --no-clobber https://docs142.rockfish.ai/tutorials/spotify-2023-short.csv
# Out:
# --2024-07-11 16:19:41--  https://docs142.rockfish.ai/tutorials/spotify-2023-short.csv
# Resolving docs142.rockfish.ai (docs142.rockfish.ai)... 65.8.161.27, 65.8.161.100, 65.8.161.56, ...
# Connecting to docs142.rockfish.ai (docs142.rockfish.ai)|65.8.161.27|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2759 (2.7K) [text/csv]
# Saving to: ‘spotify-2023-short.csv’
#
# spotify-2023-short. 100%[===================>]   2.69K  --.-KB/s    in 0s
#
# 2024-07-11 16:19:41 (1.28 GB/s) - ‘spotify-2023-short.csv’ saved [2759/2759]

# %%
dataset = rf.Dataset.from_csv("Spotify", "spotify-2023-short.csv")
dataset.to_pandas()
# Out:
#     released_year  released_month  released_day  in_spotify_playlists  bpm  \
# 0            2023               7            14                   553  125
# 1            2023               3            23                  1474   92
# 2            2023               6            30                  1397  138
# 3            2019               8            23                  7858  170
# 4            2023               5            18                  3133  144
# ..            ...             ...           ...                   ...  ...
# 95           2023               5            12                  2175  143
# 96           2023               3            17                  2000  100
# 97           2022              12             9                  2839  143
# 98           2011               1             1                 20333  112
# 99           2023               6             9                   674   93
#
#    key   mode
# 0    B  Major
# 1   C#  Major
# 2    F  Major
# 3    A  Major
# 4    A  Minor
# ..  ..    ...
# 95  D#  Major
# 96  F#  Minor
# 97   F  Major
# 98  C#  Minor
# 99   G  Major
#
# [100 rows x 7 columns]

# %%
cat_fields = "released_year released_month released_day key mode".split()
con_fields = "in_spotify_playlists bpm".split()
config = {
    "encoder": {
        "metadata": [{"field": col, "type": "categorical"} for col in cat_fields]
        + [{"field": col, "type": "continuous"} for col in con_fields]
    },
    "rtf": {
        "mode": "tabular",
        "num_bootstrap": 2,
        "tabular": {
            "epochs": 1,
            "transformer": {"gpt2_config": {"layer": 1, "head": 1, "embed": 1}},
        },
    },
}
# create the train action
train = ra.TrainTransformer(config)

# %%
builder = rf.WorkflowBuilder()
builder.add_dataset(dataset)
builder.add_action(train, parents=[dataset])
workflow = await builder.start(conn)

print(f"Workflow: {workflow.id()}")
# Out:
# Workflow: 1rpK8gO8nMdg8wDy5QGwLx

# %%
async for log in workflow.logs():
    print(log)
# Out:
# 2024-07-11T23:19:42Z dataset-load: INFO Loading dataset '2pfw1YsCftFvd4VH2APyTm' with 100 rows
# 2024-07-11T23:20:06Z train-transformer: INFO Start training...
# 2024-07-11T23:20:09Z train-transformer: INFO Epoch 1 completed.
# 2024-07-11T23:20:19Z train-transformer: INFO Training completed. The Model ID is 22de2952-3fdc-11ef-a604-66d5dda6bc83

# %%
model = await workflow.models().last()
model
# Out:
# Model('22de2952-3fdc-11ef-a604-66d5dda6bc83')

# %%
generate = ra.GenerateTransformer(config)
save = ra.DatasetSave({"name": "synthetic"})
builder = rf.WorkflowBuilder()
builder.add_model(model)
builder.add_action(generate, parents=[model])
builder.add_action(save, parents=[generate])
workflow = await builder.start(conn)
print(f"Workflow: {workflow.id()}")
# Out:
# Workflow: UCxSdCqAg67sSOvTXInye

# %%
async for log in workflow.logs():
    print(log)
# Out:
# 2024-07-11T23:20:21Z generate-transformer: INFO Starting download of Model 22de2952-3fdc-11ef-a604-66d5dda6bc83
# 2024-07-11T23:20:26Z generate-transformer: INFO Finished download of Model 22de2952-3fdc-11ef-a604-66d5dda6bc83
# 2024-07-11T23:20:26Z generate-transformer: INFO Start generating samples...
# 2024-07-11T23:20:26Z generate-transformer: INFO Finish generating samples...
# 2024-07-11T23:20:26Z dataset-save: INFO Saved dataset '63h6bHsINjD0cNjSp0GGf' with 100 rows

# %%
syn = None
async for sds in workflow.datasets():
    syn = await sds.to_local(conn)
syn.table = syn.table.select(
    "released_year released_month released_day in_spotify_playlists bpm key mode".split()
)
syn.to_pandas()
# Out:
#     released_year  released_month  released_day  in_spotify_playlists  bpm  \
# 0            2029               3            13                  2415   61
# 1            2029              11            13                 13523   62
# 2            2017               4             3                  7428   20
# 3            2023               2             5                  5809  108
# 4            2026               9            35                 42257  109
# ..            ...             ...           ...                   ...  ...
# 95           2071              16            31                 27804  183
# 96           2020               2            25                  3772  169
# 97           2022               3             4                  2531  124
# 98           2022               9            21                 16839  128
# 99           2975               2            13                  6471  128
#
#    key   mode
# 0    D  Major
# 1   A#  Major
# 2    E  Major
# 3    A  Minor
# 4       Major
# ..  ..    ...
# 95   F  Major
# 96  G#  Minor
# 97   F  Minor
# 98   F  Major
# 99  A#  Minor
#
# [100 rows x 7 columns]

# %% [markdown]
# ### Evaluation
#
# **1. Categorical columns**

# %%
for col in ["released_year", "mode"]:
    source_agg = rf.metrics.count_all(dataset, col, nlargest=10)
    syn_agg = rf.metrics.count_all(syn, col, nlargest=10)
    rf.labs.vis.plot_bar([source_agg, syn_agg], col, f"{col}_count")

# %% [markdown]
# **2. numerical columns**

# %%
for col in ["in_spotify_playlists", "bpm"]:
    rf.labs.vis.plot_kde([dataset, syn], col)
